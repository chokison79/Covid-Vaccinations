# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\mail\anaconda3\lib\site-packages (2.9.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the dependencies 
import pandas as pd
from sqlalchemy import create_engine, inspect

# %% [markdown]
# ### Read the files into pandas dataframe and display

# %%
percapita_df = pd.read_csv("../Resources/GDP_PerCapita2.csv")
percapita_df.head()
# Out:
#   Country/Territory         Country         Subregion    Region  \
# 0           Monaco�          Monaco    Western Europe    Europe
# 1    Liechtenstein�   Liechtenstein    Western Europe    Europe
# 2       Luxembourg�      Luxembourg    Western Europe    Europe
# 3          Bermuda�         Bermuda  Northern America  Americas
# 4   Cayman Islands�  Cayman Islands         Caribbean  Americas
#
#    GDP Estimate in USD per capita as per IMF  Year as per IMF  \
# 0                                        NaN              NaN
# 1                                        NaN              NaN
# 2                                   131782.0           2021.0
# 3                                        NaN              NaN
# 4                                        NaN              NaN
#
#    GDP Estimate in USD per capita as per UN Year as per UN  \
# 0                                  190532.0           2019
# 1                                  179258.0           2019
# 2                                  115481.0           2019
# 3                                  117768.0           2019
# 4                                   92692.0           2019
#
#    GDP Estimate in USD per capita as per World Bank  Year as per World Bank
# 0                                          190513.0                  2019.0
# 1                                          180367.0                  2018.0
# 2                                          115874.0                  2020.0
# 3                                          117098.0                  2019.0
# 4                                           91393.0                  2019.0

# %%
global_vax_df = pd.read_csv("../Resources/Global_COVID_Vaccination_Tracker.csv")
global_vax_df.head()
# Out:
#   Countries and regions  Doses administered  Enough for % of people  \
# 0          Global Total        5.663213e+09                     NaN
# 1        Mainland China        2.129833e+09                    76.1
# 2                 India        7.303371e+08                    26.7
# 3                    EU        5.469671e+08                    61.6
# 4                  U.S.        3.785697e+08                    59.2
#
#    Percentage of population with 1+ dose  \
# 0                                    NaN
# 1                                    NaN
# 2                                   40.3
# 3                                   66.0
# 4                                   62.9
#
#    Percentage of population fully vaccinated  Daily rate of doses administered
# 0                                        NaN                        33380378.0
# 1                                       69.3                         6454714.0
# 2                                       12.4                         7616167.0
# 3                                       61.5                         1394444.0
# 4                                       53.6                          721844.0

# %%
population_df = pd.read_csv("../Resources/population_by_country_2020.csv")
population_df.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# 2        83 %      4.25 %
# 3        56 %      3.51 %
# 4        35 %      2.83 %

# %% [markdown]
# ### Find the null and duplicates in the dataframes

# %%
#find null values in percpaita_df 
null_percapita = percapita_df[percapita_df.isna().any(axis=1)]
null_percapita
# Out:
#            Country/Territory                 Country         Subregion  \
# 0                    Monaco�                  Monaco    Western Europe
# 1             Liechtenstein�           Liechtenstein    Western Europe
# 3                   Bermuda�                 Bermuda  Northern America
# 4            Cayman Islands�          Cayman Islands         Caribbean
# 17                Greenland�               Greenland  Northern America
# 21   British Virgin Islands�  British Virgin Islands         Caribbean
# 31                  Andorra�                 Andorra   Southern Europe
# 33            New Caledonia�           New Caledonia         Melanesia
# 38                   Taiwan�                  Taiwan      Eastern Asia
# 43             Sint Maarten�            Sint Maarten         Caribbean
# 46        Turks and Caicos I       Turks and Caicos          Caribbean
# 48                 Anguilla�                Anguilla         Caribbean
# 54             Cook Islands�            Cook Islands         Polynesia
# 56         French Polynesia�        French Polynesia         Polynesia
# 61                  Cura�ao�                 Cura�ao         Caribbean
# 74               Montserrat�              Montserrat         Caribbean
# 79           American Samoa�          American Samoa         Polynesia
# 80                   #VALUE!                 #VALUE!               NaN
# 89                     Cuba�                    Cuba         Caribbean
# 201             North Korea�             North Korea      Eastern Asia
#
#        Region  GDP Estimate in USD per capita as per IMF  Year as per IMF  \
# 0      Europe                                        NaN              NaN
# 1      Europe                                        NaN              NaN
# 3    Americas                                        NaN              NaN
# 4    Americas                                        NaN              NaN
# 17   Americas                                        NaN              NaN
# 21   Americas                                        NaN              NaN
# 31     Europe                                        NaN              NaN
# 33    Oceania                                        NaN              NaN
# 38       Asia                                    32123.0           2021.0
# 43   Americas                                        NaN              NaN
# 46   Americas                                        NaN              NaN
# 48   Americas                                        NaN              NaN
# 54    Oceania                                        NaN              NaN
# 56    Oceania                                        NaN              NaN
# 61   Americas                                        NaN              NaN
# 74   Americas                                        NaN              NaN
# 79    Oceania                                        NaN              NaN
# 80        NaN                                        NaN              NaN
# 89   Americas                                        NaN              NaN
# 201      Asia                                        NaN              NaN
#
#      GDP Estimate in USD per capita as per UN Year as per UN  \
# 0                                    190532.0           2019
# 1                                    179258.0           2019
# 3                                    117768.0           2019
# 4                                     92692.0           2019
# 17                                    53353.0           2019
# 21                                    48511.0           2019
# 31                                    40887.0           2019
# 33                                    34942.0           2019
# 38                                    28371.0     [6][7]2020
# 43                                        NaN            NaN
# 46                                    31353.0           2019
# 48                                    25529.0           2019
# 54                                    21603.0           2019
# 56                                    21567.0           2019
# 61                                    18980.0           2019
# 74                                    13487.0           2019
# 79                                        NaN            NaN
# 80                                    11339.0           2019
# 89                                     9296.0           2019
# 201                                     640.0           2019
#
#      GDP Estimate in USD per capita as per World Bank  Year as per World Bank
# 0                                            190513.0                  2019.0
# 1                                            180367.0                  2018.0
# 3                                            117098.0                  2019.0
# 4                                             91393.0                  2019.0
# 17                                            54471.0                  2018.0
# 21                                                NaN                     NaN
# 31                                            40897.0                  2019.0
# 33                                            12580.0                  2000.0
# 38                                                NaN                     NaN
# 43                                            29160.0                  2018.0
# 46                                            23880.0                  2020.0
# 48                                                NaN                     NaN
# 54                                                NaN                     NaN
# 56                                            14324.0                  2000.0
# 61                                            19701.0                  2019.0
# 74                                                NaN                     NaN
# 79                                            11535.0                  2019.0
# 80                                            10926.0                  2020.0
# 89                                             9100.0                  2019.0
# 201                                               NaN                     NaN

# %%
#finding which GDP data has least null values 

wb_series = pd.isnull(percapita_df["GDP Estimate in USD per capita as per World Bank"])

un_series = pd.isnull(percapita_df["GDP Estimate in USD per capita as per UN"])

imf_series = pd.isnull(percapita_df["GDP Estimate in USD per capita as per IMF"])

print(f"number of null values in worldbank gdp data is {len(percapita_df[wb_series])}" )
print(f"number of null values in UN gdp data is {len(percapita_df[un_series])}" )
print(f"number of null values in IMF gdp data is {len(percapita_df[imf_series])}" )
# Out:
# number of null values in worldbank gdp data is 6
# number of null values in UN gdp data is 2
# number of null values in IMF gdp data is 19

# %%
#keeping the gdp and year columns with least null values and dropping rest
new_percapita_df = percapita_df [["Country","Region","GDP Estimate in USD per capita as per UN","Year as per UN"]]
new_percapita_df.head()
# Out:
#           Country    Region  GDP Estimate in USD per capita as per UN  \
# 0          Monaco    Europe                                  190532.0
# 1   Liechtenstein    Europe                                  179258.0
# 2      Luxembourg    Europe                                  115481.0
# 3         Bermuda  Americas                                  117768.0
# 4  Cayman Islands  Americas                                   92692.0
#
#   Year as per UN
# 0           2019
# 1           2019
# 2           2019
# 3           2019
# 4           2019

# %%
# drop the duplicates 
new_percapita_df = new_percapita_df.drop_duplicates(subset =["Country"], keep = "first")
new_percapita_df.head()
# Out:
#           Country    Region  GDP Estimate in USD per capita as per UN  \
# 0          Monaco    Europe                                  190532.0
# 1   Liechtenstein    Europe                                  179258.0
# 2      Luxembourg    Europe                                  115481.0
# 3         Bermuda  Americas                                  117768.0
# 4  Cayman Islands  Americas                                   92692.0
#
#   Year as per UN
# 0           2019
# 1           2019
# 2           2019
# 3           2019
# 4           2019

# %%
#find the null values in the global_vax_df
null_global_vax = global_vax_df[global_vax_df.isna().any(axis=1)]
null_global_vax
# Out:
#     Countries and regions  Doses administered  Enough for % of people  \
# 0            Global Total        5.663213e+09                     NaN
# 1          Mainland China        2.129833e+09                    76.1
# 93               Ethiopia        2.654956e+06                     1.4
# 140                 Syria        4.032540e+05                     NaN
# 148              Tanzania        3.101030e+05                     0.3
# 158               Lesotho        2.017950e+05                     4.9
# 161                 Benin        1.740740e+05                     0.7
# 164                Jersey        1.497480e+05                     NaN
# 176              Guernsey        1.009570e+05                     NaN
# 185            Micronesia        6.774800e+04                    32.6
# 198          Turkmenistan        4.199300e+04                     0.4
# 202                 Nauru        1.479000e+04                    56.9
# 205            Montserrat        2.837000e+03                    28.4
# 206               Eritrea                 NaN                     NaN
#
#      Percentage of population with 1+ dose  \
# 0                                      NaN
# 1                                      NaN
# 93                                     2.7
# 140                                    NaN
# 148                                    NaN
# 158                                    2.0
# 161                                    1.3
# 164                                    NaN
# 176                                    NaN
# 185                                   37.7
# 198                                    0.6
# 202                                   58.6
# 205                                   29.3
# 206                                    NaN
#
#      Percentage of population fully vaccinated  \
# 0                                          NaN
# 1                                         69.3
# 93                                         NaN
# 140                                        NaN
# 148                                        NaN
# 158                                        NaN
# 161                                        NaN
# 164                                        NaN
# 176                                        NaN
# 185                                        NaN
# 198                                        0.2
# 202                                       55.2
# 205                                       27.4
# 206                                        NaN
#
#      Daily rate of doses administered
# 0                          33380378.0
# 1                           6454714.0
# 93                            27945.0
# 140                            2105.0
# 148                            5718.0
# 158                           24504.0
# 161                            2375.0
# 164                             142.0
# 176                             181.0
# 185                             219.0
# 198                               NaN
# 202                               NaN
# 205                               NaN
# 206                               NaN

# %%
#final dataframe for global_vax_df
new_global_vax = global_vax_df[["Countries and regions","Doses administered","Percentage of population with 1+ dose"
                                ,"Percentage of population fully vaccinated"]]
new_global_vax.head()
# Out:
#   Countries and regions  Doses administered  \
# 0          Global Total        5.663213e+09
# 1        Mainland China        2.129833e+09
# 2                 India        7.303371e+08
# 3                    EU        5.469671e+08
# 4                  U.S.        3.785697e+08
#
#    Percentage of population with 1+ dose  \
# 0                                    NaN
# 1                                    NaN
# 2                                   40.3
# 3                                   66.0
# 4                                   62.9
#
#    Percentage of population fully vaccinated
# 0                                        NaN
# 1                                       69.3
# 2                                       12.4
# 3                                       61.5
# 4                                       53.6

# %%
#final dataframe for the population_df
new_population_df = population_df[["Country (or dependency)","Population (2020)"]]
new_population_df.head()
# Out:
#   Country (or dependency)  Population (2020)
# 0                   China         1440297825
# 1                   India         1382345085
# 2           United States          331341050
# 3               Indonesia          274021604
# 4                Pakistan          221612785

# %%
#find the null values in the global_vax_df
null_population = new_population_df[new_population_df.isna().any(axis=1)]
null_population
# Out:
# Empty DataFrame
# Columns: [Country (or dependency), Population (2020)]
# Index: []

# %%
country_correspondence = pd.read_csv("../Resources/country_correspondence.csv")
country_correspondence.head()
# Out:
#    Index             Pop              GDP           GDP-1        Covid  \
# 0    0.0     Afghanistan     Afghanistan      Afghanistan  Afghanistan
# 1    1.0         Albania         Albania          Albania      Albania
# 2    2.0         Algeria         Algeria          Algeria      Algeria
# 3    3.0  American Samoa  American Samoa   American Samoa          NaN
# 4    4.0         Andorra         Andorra          Andorra      Andorra
#
#   Full_set  Unnamed: 6  Unnamed: 7
# 0     True         NaN         4.0
# 1     True         NaN         4.0
# 2     True         NaN         4.0
# 3    False         NaN         3.0
# 4     True         NaN         4.0

# %%
merge_pop = country_correspondence[["Index","Pop"]]
merge_pop = merge_pop.rename(columns={"Pop":"Country (or dependency)"})
merge_pop.head()
# Out:
#    Index Country (or dependency)
# 0    0.0             Afghanistan
# 1    1.0                 Albania
# 2    2.0                 Algeria
# 3    3.0          American Samoa
# 4    4.0                 Andorra

# %%
merged_population = pd.merge(new_population_df, merge_pop, on="Country (or dependency)")
merged_population.head()
# Out:
#   Country (or dependency)  Population (2020)  Index
# 0                   China         1440297825   43.0
# 1                   India         1382345085   97.0
# 2           United States          331341050  228.0
# 3               Indonesia          274021604   98.0
# 4                Pakistan          221612785  162.0

# %%
merge_vax = country_correspondence[["Index","Covid"]]
merge_vax = merge_vax.rename(columns={"Covid":"Countries and regions"})
merged_vax = pd.merge(new_global_vax, merge_vax, on="Countries and regions")
merged_vax.head()
# Out:
#   Countries and regions  Doses administered  \
# 0        Mainland China        2.129833e+09
# 1                 India        7.303371e+08
# 2                    EU        5.469671e+08
# 3                  U.S.        3.785697e+08
# 4                Brazil        2.058668e+08
#
#    Percentage of population with 1+ dose  \
# 0                                    NaN
# 1                                   40.3
# 2                                   66.0
# 3                                   62.9
# 4                                   66.9
#
#    Percentage of population fully vaccinated  Index
# 0                                       69.3   43.0
# 1                                       12.4   97.0
# 2                                       61.5   67.0
# 3                                       53.6  228.0
# 4                                       33.2   27.0

# %%
merge_gdp = country_correspondence[["Index","GDP-1"]]
merge_gdp = merge_gdp.rename(columns={"GDP-1":"Country"})
merged_gdp = pd.merge(new_percapita_df, merge_gdp, on="Country")
merged_gdp.head()
# Out:
#           Country    Region  GDP Estimate in USD per capita as per UN  \
# 0          Monaco    Europe                                  190532.0
# 1   Liechtenstein    Europe                                  179258.0
# 2      Luxembourg    Europe                                  115481.0
# 3         Bermuda  Americas                                  117768.0
# 4  Cayman Islands  Americas                                   92692.0
#
#   Year as per UN  Index
# 0           2019  140.0
# 1           2019  122.0
# 2           2019  124.0
# 3           2019   22.0
# 4           2019   38.0

# %%
merge_1 = pd.merge(merged_population, merged_vax, on="Index")
merge_1.head()
# Out:
#   Country (or dependency)  Population (2020)  Index Countries and regions  \
# 0                   China         1440297825   43.0        Mainland China
# 1                   India         1382345085   97.0                 India
# 2           United States          331341050  228.0                  U.S.
# 3               Indonesia          274021604   98.0             Indonesia
# 4                Pakistan          221612785  162.0              Pakistan
#
#    Doses administered  Percentage of population with 1+ dose  \
# 0        2.129833e+09                                    NaN
# 1        7.303371e+08                                   40.3
# 2        3.785697e+08                                   62.9
# 3        1.115708e+08                                   26.3
# 4        6.645624e+07                                   24.5
#
#    Percentage of population fully vaccinated
# 0                                       69.3
# 1                                       12.4
# 2                                       53.6
# 3                                       15.1
# 4                                       10.4

# %%
merge_2 = pd.merge(merge_1, merged_gdp, on="Index")
merge_2.head()
# Out:
#   Country (or dependency)  Population (2020)  Index Countries and regions  \
# 0                   China         1440297825   43.0        Mainland China
# 1                   India         1382345085   97.0                 India
# 2           United States          331341050  228.0                  U.S.
# 3               Indonesia          274021604   98.0             Indonesia
# 4                Pakistan          221612785  162.0              Pakistan
#
#    Doses administered  Percentage of population with 1+ dose  \
# 0        2.129833e+09                                    NaN
# 1        7.303371e+08                                   40.3
# 2        3.785697e+08                                   62.9
# 3        1.115708e+08                                   26.3
# 4        6.645624e+07                                   24.5
#
#    Percentage of population fully vaccinated        Country    Region  \
# 0                                       69.3          China      Asia
# 1                                       12.4          India      Asia
# 2                                       53.6  United States  Americas
# 3                                       15.1      Indonesia      Asia
# 4                                       10.4       Pakistan      Asia
#
#    GDP Estimate in USD per capita as per UN Year as per UN
# 0                                   10004.0           2019
# 1                                    2116.0           2019
# 2                                   65134.0           2019
# 3                                    4136.0           2019
# 4                                    1187.0           2019

# %%
final_merge = merge_2[["Country", "Population (2020)", "GDP Estimate in USD per capita as per UN", "Doses administered", "Percentage of population with 1+ dose", "Percentage of population fully vaccinated", "Region"]]
final_merge = final_merge.rename(columns={
    "Country":"country",
    "Population (2020)":"population",
    "GDP Estimate in USD per capita as per UN":"gdp_per_capita",
    "Doses administered":"doses",
    "Percentage of population with 1+ dose":"pc_1_dose",
    "Percentage of population fully vaccinated":"pc_2_doses",
    "Region":"world_region"
})
final_merge.head()
# Out:
#          country  population  gdp_per_capita         doses  pc_1_dose  \
# 0          China  1440297825         10004.0  2.129833e+09        NaN
# 1          India  1382345085          2116.0  7.303371e+08       40.3
# 2  United States   331341050         65134.0  3.785697e+08       62.9
# 3      Indonesia   274021604          4136.0  1.115708e+08       26.3
# 4       Pakistan   221612785          1187.0  6.645624e+07       24.5
#
#    pc_2_doses world_region
# 0        69.3         Asia
# 1        12.4         Asia
# 2        53.6     Americas
# 3        15.1         Asia
# 4        10.4         Asia

# %%
final_merge.to_csv("../Resources/clean_data.csv")

# %%
from config import username, password

conn_string = f"postgresql://{username}:{password}@localhost:5432/covid"

engine = create_engine(conn_string)

# %%
final_merge.to_sql(name='vaccination_record', con=engine, if_exists='append', index=False)
